# %%
import pandas as pd
# Out:
# /Users/pavelesipenok/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('/Users/pavelesipenok/ASKONA/Ormatek.csv')
df.head(2)
df_2 = df

# %%
df['Review_Text'] = df['Review_Text'].apply(lambda x: "Что мне нравится в работодателе: " + x)
df['Review_Text'] = df['Review_Text'].apply(lambda x: x.replace('<separator>', 'Что можно было бы улучшить: '))

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("MonoHime/rubert-base-cased-sentiment-new")
model = AutoModelForSequenceClassification.from_pretrained("MonoHime/rubert-base-cased-sentiment-new")

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model = model, tokenizer = tokenizer)

result = classifier("Что мне нравится в работодателеработаю на производстве технологом, работа хорошая, интересная. особенно мне нравится график (с 8 до 17, 5/2), сама специфика работы, наличие разных бонусов. Зарплата тоже неплохая, выходит 60 тысяч в месяц, нам с женой более чем хватает.Что можно было бы улучшитьминусов в работе не нашел, есть только мой минус - иногда ну очень уж лениво работать, но я пытаюсь", top_k=None)
print(result[0]['label'])
print(result[1]['score'])
print(result[2]['label'])
print(result)
# Out:
# POSITIVE
# 0.03282395005226135
# NEGATIVE
# [{'label': 'POSITIVE', 'score': 0.9584789872169495}, {'label': 'NEUTRAL', 'score': 0.03282395005226135}, {'label': 'NEGATIVE', 'score': 0.008697130717337132}]

# %%
def sentiment_score(review):
    result = classifier(review, top_k=None)
    return result[0]['label']

df['sentiment'] = df['Review_Text'].apply(lambda x: sentiment_score(x))

# %%
df_counted = df.groupby('sentiment').agg({"sentiment": 'count'}).rename(columns = {'sentiment' : 'SUM'})
df_counted.reset_index()
# Out:
#   sentiment  SUM
# 0  NEGATIVE   22
# 1   NEUTRAL   75
# 2  POSITIVE  238

# %%
webinar_pie = df_counted.plot(kind = 'pie', y='SUM', autopct="%.0f%%", colormap='Wistia')

webinar_pie.set_title('Ormatek Sentiment proportion')
webinar_pie.legend(bbox_to_anchor= (1.01, 1))
webinar_pie.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
dfa = df[['Perks_Tags']]
ddd = dfa['Perks_Tags'].to_list()
lists = [eval(item) for item in ddd]
merged_list = [item for sublist in lists for item in sublist]
final_perks = pd.DataFrame(merged_list, columns=["Perks"])

# %%
plot_final = final_perks.groupby("Perks").agg({"Perks" : 'count'}).rename(columns = {'Perks' : 'Counter'}).reset_index().sort_values('Counter', ascending = False)
plot_final
# Out:
#                              Perks  Counter
# 10      Своевременная оплата труда      275
# 6               Оплата больничного      208
# 13     Удобное расположение работы      191
# 9        Профессиональное обучение      137
# 5   Наличие кухни, места для обеда       99
# 11          Система наставничества       98
# 0            Гибкий рабочий график       82
# 1        Корпоративные мероприятия       62
# 2          Корпоративный транспорт       54
# 12                Удаленная работа       47
# 7           Оплата мобильной связи       44
# 4               Место для парковки       43
# 8     Оплата транспортных расходов       22
# 3          Медицинское страхование       16

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Предварительная обработка данных (сортировка по счетчику)

# Создание графика
plt.figure(figsize=(10, 6))
sns.barplot(x='Counter', y='Perks', data=plot_final, color='orange')
plt.xlabel('Counter')
plt.ylabel('Perks')
plt.title('Распределение перков')
plt.show()

# %%
month_dict = {'Январь': 'January', 'Февраль': 'February', 'Март': 'March', 'Апрель': 'April', 'Май': 'May', 'Июнь': 'June', 'Июль': 'July', 'Август': 'August', 'Сентябрь': 'September', 'Октябрь': 'October', 'Ноябрь': 'November', 'Декабрь': 'December'}

# Замена названий месяцев на английский формат
df['Date'] = df['Date'].apply(lambda x: x.split())
df['Date'] = df['Date'].apply(lambda x: month_dict[x[0]] + ' ' + x[1])

# Преобразование строки даты в формат datetime
df['Date'] = pd.to_datetime(df['Date'], format='%B %Y', errors='coerce')

# %%
df.head(2)
# Out:
#    Unnamed: 0  Review_ID                       Header          Date  \
# 0           0    2045260  Руководитель службы сервиса  Октябрь 2023
# 1           1    2323196         Продавец-консультант  Февраль 2024
#
#                                          Header_Tags  \
# 0  ['Бывший сотрудник', 'Стаж в компании: Больше ...
# 1  ['Бывший сотрудник', 'Стаж в компании: 3-5 лет...
#
#                                           Perks_Tags  Rating_Data  \
# 0  ['Своевременная оплата труда', 'Наличие кухни,...  5,5,5,5,3,5
# 1  ['Своевременная оплата труда', 'Медицинское ст...  4,4,3,4,3,3
#
#                                          Review_Text  Helpful_Count  \
# 0  Что мне нравится в работодателе: Адекватное от...              0
# 1  Что мне нравится в работодателе: Стабильность ...              0
#
#    Employer_Response_Date  Employer_Response_Title  Employer_Response_Msg  \
# 0                     NaN                      NaN                    NaN
# 1                     NaN                      NaN                    NaN
#
#                                          Review_Link  Working Conditions  \
# 0  https://dreamjob.ru/employers/41369?review_id=...                   5
# 1  https://dreamjob.ru/employers/41369?review_id=...                   4
#
#    Income Level  Team  Management  Recreation Opportunities  \
# 0             5     5           5                         3
# 1             4     3           4                         3
#
#    Growth Opportunities sentiment
# 0                     5  POSITIVE
# 1                     3   NEUTRAL

# %%
text1 = " ".join(title for title in df.Title)
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text1)
word_cloud1

plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_2['positive_review'] = df_2['Review_Text'].apply(lambda x: x.split('<separator>')[0])

# %%
df_2['negative_review'] = df_2['Review_Text'].apply(lambda x: x.split('<separator>')[1])

# %%
df_2.head(2)
# Out:
#    Unnamed: 0  Review_ID                       Header          Date  \
# 0           0    2045260  Руководитель службы сервиса  Октябрь 2023
# 1           1    2323196         Продавец-консультант  Февраль 2024
#
#                                          Header_Tags  \
# 0  ['Бывший сотрудник', 'Стаж в компании: Больше ...
# 1  ['Бывший сотрудник', 'Стаж в компании: 3-5 лет...
#
#                                           Perks_Tags  Rating_Data  \
# 0  ['Своевременная оплата труда', 'Наличие кухни,...  5,5,5,5,3,5
# 1  ['Своевременная оплата труда', 'Медицинское ст...  4,4,3,4,3,3
#
#                                          Review_Text  Helpful_Count  \
# 0  Адекватное отношение руководителей, возможност...              0
# 1  Стабильность в зп и хорошая школа обучения. Ес...              0
#
#    Employer_Response_Date  ...  Employer_Response_Msg  \
# 0                     NaN  ...                    NaN
# 1                     NaN  ...                    NaN
#
#                                          Review_Link Working Conditions  \
# 0  https://dreamjob.ru/employers/41369?review_id=...                  5
# 1  https://dreamjob.ru/employers/41369?review_id=...                  4
#
#    Income Level  Team  Management  Recreation Opportunities  \
# 0             5     5           5                         3
# 1             4     3           4                         3
#
#    Growth Opportunities                                    positive_review  \
# 0                     5  Адекватное отношение руководителей, возможност...
# 1                     3  Стабильность в зп и хорошая школа обучения. Ес...
#
#                                      negative_review
# 0  Повысить заработную плату. Расширить соц пакет...
# 1  Коммуникация между сотрудниками, корпоративная...
#
# [2 rows x 21 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud

# %%
text1 = " ".join(title for title in df_2.positive_review)

# %%
# Предварительно определенный список стоп-слов
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

df_2['positive_review'] = df_2['Review_Text'].apply(lambda x: x.split('<separator>')[0])
df_2['negative_review'] = df_2['Review_Text'].apply(lambda x: x.split('<separator>')[1])

text1 = " ".join(title.lower() for title in df_2.positive_review)
text2 = " ".join(title.lower() for title in df_2.negative_review)

def remove_stop_words(text):
    russian_stop_words = stopwords.words('russian')  # Загрузка списка стоп-слов на русском
    words = text.split()  # Разбиваем текст на слова
    filtered_words = [word for word in words if word.lower() not in russian_stop_words]  # Фильтруем стоп-слова
    return ' '.join(filtered_words)  # Собираем обратно в строку

                                   
text_without_stop_words_1 = remove_stop_words(text1)
text_without_stop_words_2 = remove_stop_words(text2)

# Пример использования функции
text_without_stop_words = remove_stop_words(text_without_stop_words_1)
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text_without_stop_words)
word_cloud1

plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()


text_without_stop_words = remove_stop_words(text_without_stop_words_2)
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text_without_stop_words)
word_cloud1

plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pavelesipenok/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
это работы

# %%
# Пример использования функции
text_without_stop_words = remove_stop_words(text_without_stop_words)
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text_without_stop_words)
word_cloud1

plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text1 = " ".join(title for title in df_2.positive_review)
word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text1)
word_cloud1

plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]     /Users/pavelesipenok/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
# True

# %%
import pymorphy2  # $ pip install pymorphy2

def pos(text1, morth=pymorphy2.MorphAnalyzer()):
    "Return a likely part of speech for the *word*."""
    return morth.parse(text1)[0].tag.POS

words = text1.split()
functors_pos = {'INTJ', 'PRCL', 'CONJ', 'PREP'}  # function words
print(*[word for word in words if pos(word) not in functors_pos])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 import pymorphy2  # $ pip install pymorphy2
# ----> 3 def pos(text1, morth=pymorphy2.MorphAnalyzer()):
#       4     "Return a likely part of speech for the *word*."""
#       5     return morth.parse(text1)[0].tag.POS
#
# File ~/anaconda3/lib/python3.11/site-packages/pymorphy2/analyzer.py:224, in MorphAnalyzer.__init__(self, path, lang, result_type, units, probability_estimator_cls, char_substitutes)
#     222 self._result_type_orig = result_type
#     223 self._init_char_substitutes(char_substitutes)
# --> 224 self._init_units(units)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymorphy2/analyzer.py:235, in MorphAnalyzer._init_units(self, units_unbound)
#     233 if isinstance(item, (list, tuple)):
#     234     for unit in item[:-1]:
# --> 235         self._units.append((self._bound_unit(unit), False))
#     236     self._units.append((self._bound_unit(item[-1]), True))
#     237 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pymorphy2/analyzer.py:246, in MorphAnalyzer._bound_unit(self, unit)
#     245 def _bound_unit(self, unit):
# --> 246     unit = unit.clone()
#     247     unit.init(self)
#     248     return unit
#
# File ~/anaconda3/lib/python3.11/site-packages/pymorphy2/units/base.py:35, in BaseAnalyzerUnit.clone(self)
#      34 def clone(self):
# ---> 35     return self.__class__(**self._get_params())
#
# File ~/anaconda3/lib/python3.11/site-packages/pymorphy2/units/base.py:76, in BaseAnalyzerUnit._get_params(self)
#      73 def _get_params(self):
#      74     """ Return a dict with the parameters for this analyzer unit. """
#      75     return dict(
# ---> 76         (key, getattr(self, key, None)) for key in self._get_param_names()
#      77     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pymorphy2/units/base.py:70, in BaseAnalyzerUnit._get_param_names(cls)
#      68 if cls.__init__ is object.__init__:
#      69     return []
# ---> 70 args, varargs, kw, default = inspect.getargspec(cls.__init__)
#      71 return sorted(args[1:])
#
# AttributeError: module 'inspect' has no attribute 'getargspec'

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

text = "Nick likes to play football, however he is not too fond of tennis."
text_tokens = word_tokenize(text)

tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]

print(tokens_without_sw)

# %%
text1 = " ".join(title for title in df_2.positive_review)

# %%
from nltk.corpus import stopwords
stopwords.words('')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/Users/pavelesipenok/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/share/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[45], line 2
#       1 from nltk.corpus import stopwords
# ----> 2 stopwords.words('russia')
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/Users/pavelesipenok/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/share/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
from nltk.corpus import stopwords
stopwords.words('russian')

filtered_words = [word for word in text1 if word not in stopwords.words('russian')]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/Users/pavelesipenok/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/share/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[43], line 2
#       1 from nltk.corpus import stopwords
# ----> 2 stopwords.words('russian')
#       4 filtered_words = [word for word in text1 if word not in stopwords.words('russian')]
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/Users/pavelesipenok/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/share/nltk_data'
#     - '/Users/pavelesipenok/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
1. Облако слов
2. Общее кол во отзывов поделить на негативные и позитивные
3.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 ва
#
# NameError: name 'ва' is not defined

# %%
1. https://dreamjob.ru/employers/41369
2.
